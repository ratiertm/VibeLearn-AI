# %% [markdown]
# # 01. 개발환경 세팅 확인
#
# **모듈**: M1 - Python 기초 + 개발환경 세팅
# **날짜**: 2026-03-09
#
# 이 노트북은 개발환경이 올바르게 설치되었는지 확인합니다.

# %%
import torch
import numpy as np
import matplotlib

print(f'Python 환경 확인')
print(f'==================')
print(f'PyTorch:    {torch.__version__}')
print(f'NumPy:      {np.__version__}')
print(f'Matplotlib: {matplotlib.__version__}')
print(f'MPS (Mac GPU): {torch.backends.mps.is_available()}')
print(f'\n✅ 모든 패키지 정상!')
